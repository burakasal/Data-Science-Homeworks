# %% [markdown]
# #Homework 2: Drug Side Effects
#
# *In the second homework, you are going to work with SIDER side effects dataset.*
#
# **Submission Instructions**
#
# ---
# It is important that you follow the submission instructions.
# 1. Copy this assignment notebook to your Drive. <font color = 'red'> `File` --> `Save a copy in Drive`</font>. Rename it as <font color = 'green'>`Lastname_Firstname_hw1`</font>.
#
# 2. Write your solutions in the cells  marked <font color = 'green'>`# your code`</font>.
#
# 3. Do not delete your outputs. They are essential for the grading. Make sure that cells containing your solutions are executed, and the results are displayed on the notebook.
#
# 4. When you're done please submit your solutions as an <font color="red">`.ipynb`</font> file. To do so:
#
#
# 1.  Click on <font color="red">`File`</font>  at the top left on the Colab screen, then click on <font color = 'red'>`Download .ipynb`</font>.
# 2.   Then submit the downloaded <font color="red">`.ipynb`</font> version of your work on SUCourse.
#
#
# For any question, you may send an email to the TAs and LAs.
#
# ---

# %% [markdown]
# In this homework, you will work on a dataset from [SIDER Side Effect Resource](http://sideeffects.embl.de/). SIDER contains information on marketed drugs and their recorded adverse drug reactions (ADR).
#
# For this homework, you will use the provided file `meddra_all_se.csv`. This is a modified and simplified version of the original dataset, which contains possible side effects of different drugs.
# <!-- This is not the original data file, we modified and eliminated some parts to make your work easier. -->
#
# As listed in their prospectives, drugs can cause some side effects besides their healing properties. This dataset simply contains entries of drugs and their potential side effects.
#
# In the dataset, each row has 4 attribute values separated with `,`. These attributes are described in the list below with their respective order in the dataset.
#
#
#   1.   **STITCH compound id:** Refers to ID of a particular drug
#
#   2.   **UMLS concept id:** Unified Medical Language System ID
#
#   3.   **UMLS concept id for MedDRA term**
#
#   4.   **Side effect name:** Contains the possible side effect entry.
#
# **You will consider the STITCH compound id as the id of a particular drug. Therefore, rows with the same STITCH compound id refer to possible side effects of the same particular drug.**
#
# A snapshot from the dataset containing three sample rows is also provided below.
# ```
# ...
# CID100000085,CID000010917,C0015230,Rash
# CID100000085,CID000010917,C0015397,Eye disorder
# CID100000085,CID000010917,C0015967,Body temperature increased
#
# ...
# ```
#
# *Do not forget to add the shared `meddra_all_se.csv` file to your drive and mount to your drive. Otherwise, you won't be able to read the file.*
#
# **!!!You are not allowed to use `pandas` in this homework**

# %%
import numpy as np
import matplotlib.pyplot as plt
from os.path import join

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('./drive', force_remount=True)

path_prefix = "./drive/My Drive"
# Out:
# Mounted at ./drive

# %% [markdown]
# ## Q1: Descriptive Statistics of the Dataset
#
# In this question, your task is to gather some descriptive information about the dataset. To do this, first read the provided dataset and store it in a 2 dimensional numpy array. Then, print the listed descriptive statistics about the dataset.
#
# *   Shape of the dataset, i.e. number of rows and columns
# *   Number of unique drugs
# *   Number of unique side effects

# %%
data = []
fname = "meddra_all_se.csv"
with open(join(path_prefix, fname)) as f:
  for line in f:
    rows = line.strip().split(",")
    stitch = str(rows[0])
    umls = str(rows[1])
    medra = str(rows[2])
    name = str(rows[3])
    data.append((stitch, umls, medra, name))

data = np.array(data)
print(data)
print()
print("shape: {}".format(data.shape))

unique_drug = []
unique_side_effect = []
count = 0
count2 = 0
for row in data:
  drug = row[0]
  side_effect =row[3]
  if drug not in unique_drug:
    unique_drug.append(drug)
    count +=1
  if side_effect not in unique_side_effect:
    unique_side_effect.append(side_effect)
    count2 +=1

print()
print("number of unique drugs:",count)
print("Number of unique side effects:",count2)
# Out:
# [['CID100000085' 'CID000010917' 'C0000729' 'Abdominal cramps']
#  ['CID100000085' 'CID000010917' 'C0000737' 'Abdominal pain']
#  ['CID100000085' 'CID000010917' 'C0002418' 'Amblyopia']
#  ...
#  ['CID144146714' 'CID044146714' 'C1262113' 'Lipohypertrophy']
#  ['CID144146714' 'CID044146714' 'C1272092' 'Impaired fasting glucose']
#  ['CID144146714' 'CID044146714' 'C1280433' 'Lipoatrophy']]
#
# shape: (91281, 4)
#
# number of unique drugs: 953
# Number of unique side effects: 5068

# %% [markdown]
# ## Q2: Side Effects of Drugs

# %% [markdown]
# ### Part A
#
# As explained above, side effect entries in the dataset correspond to possible side effects of different drugs.
#
# In this part, your goal is to find the drug which has the most side effects in the dataset. <!-- Print the `drug id` *(STITCH compound id)* of that drug and `number of its indications`. --> Print the `drug id` *(STITCH compound id)* of that drug and print the number of possible side effects (indications) it has.
#
# Print your results in the following format.
#
# ``` py
# drug id: CID100002771
# number of side effects: 766
# ```

# %%
data = []
fname = "meddra_all_se.csv"
with open(join(path_prefix, fname)) as f:
  for line in f:
    rows = line.strip().split(",")
    stitch = str(rows[0])
    umls = str(rows[1])
    medra = str(rows[2])
    name = str(rows[3])
    data.append((stitch, umls, medra, name))

data = np.array(data)

drugs = []
for row in data:
  drug = row[0]
  if drug not in drugs:
    drugs.append(drug)

count = 0
occurrences=[]
for drug in drugs:
  for element in data:
    if drug == element[0]:
      count += 1
  occurrences.append(count)  
  count = 0
print(occurrences)  
maximum = max(occurrences)
max_position = occurrences.index(maximum)
print("drug id:", drugs[max_position])
print("number of side effects:", maximum)
# Out:
# [68, 5, 83, 46, 1, 79, 122, 24, 5, 8, 94, 37, 162, 7, 27, 18, 29, 29, 5, 52, 14, 1, 25, 20, 38, 21, 472, 401, 115, 45, 51, 202, 76, 9, 2, 21, 59, 122, 19, 10, 56, 36, 24, 24, 57, 95, 5, 38, 24, 67, 57, 11, 12, 119, 87, 152, 151, 18, 23, 19, 10, 57, 34, 5, 170, 2, 9, 47, 17, 92, 18, 300, 172, 457, 37, 259, 45, 207, 114, 113, 299, 112, 157, 58, 25, 23, 65, 12, 150, 29, 191, 12, 79, 87, 218, 105, 190, 21, 114, 19, 114, 49, 26, 30, 10, 74, 214, 81, 104, 10, 132, 30, 8, 86, 77, 26, 60, 94, 157, 143, 47, 95, 65, 64, 108, 198, 83, 23, 104, 169, 77, 198, 39, 47, 90, 27, 15, 18, 26, 4, 123, 7, 63, 35, 113, 219, 22, 174, 23, 184, 28, 148, 58,
3, 20, 53, 19, 34, 47, 31, 41, 55, 23, 60, 22, 164, 11, 167, 14, 149, 5, 147, 272, 126, 98, 307, 106, 175, 336, 9, 95, 24, 56, 122, 118, 16, 365, 57, 54, 166, 9, 265, 84, 112, 32, 65, 72, 18, 246, 154, 171, 123, 62, 95, 206, 92, 257, 114, 87, 47, 62, 99, 727, 108, 81, 83, 70, 169, 50, 57, 41, 58, 42, 227, 134, 102, 12, 23, 25, 398, 35, 14, 181, 200, 118, 112, 112, 271, 64, 207, 58, 44, 54, 13, 74, 38, 109, 54, 99, 278, 73, 52, 143, 59, 44, 22, 48, 109, 105, 61, 4, 30, 333, 48, 31, 45, 47, 29, 27, 33, 60, 59, 20, 38, 110, 271, 64, 46, 203, 120, 340, 22, 178, 106, 304, 37, 112, 46, 54, 64, 7, 12, 168, 227, 76, 37, 59, 26, 50, 20, 18, 24, 111, 14, 147, 159, 11, 70, 16, 79, 97, 93, 116, 88, 131, 88, 109, 85, 12, 104, 34, 183, 2, 27, 3, 123, 44, 90, 9, 109, 35, 48, 105, 85, 25, 36, 375, 135, 5, 72, 130, 95, 298, 63, 57, 133, 69, 60, 20, 69, 56, 36, 30, 6, 23, 43, 127, 162, 45, 60, 20, 91, 132, 116, 44, 116, 57, 64, 104, 116, 73, 8, 23, 55, 68, 67, 60, 37, 11, 35, 8, 210, 76, 6, 93, 282, 66, 18, 7, 3, 15, 79, 27, 40, 51, 18, 95, 30, 5, 6, 105, 43, 20, 60, 17, 93, 73, 127, 131, 7, 24, 43, 22, 9, 60, 17, 19, 67, 174, 79, 174, 44, 33, 160, 95, 146, 37, 52, 106, 129, 108, 40, 21, 104, 60, 10, 11, 111, 50, 92, 15, 57, 1 ...
# drug id: CID100002771
# number of side effects: 766

# %% [markdown]
# ### Part B
#
# Now, find the number of side effects for all drugs and display its distribution as an histogram.
#
# An exemplary figure can be observed below.
#
# ![](https://i.ibb.co/7zPSnkR/hist.jpg)

# %%
data = []
fname = "meddra_all_se.csv"
with open(join(path_prefix, fname)) as f:
  for line in f:
    rows = line.strip().split(",")
    stitch = str(rows[0])
    umls = str(rows[1])
    medra = str(rows[2])
    name = str(rows[3])
    data.append((stitch, umls, medra, name))

data = np.array(data)

drugs = []
for row in data:
  drug = row[0]
  if drug not in drugs:
    drugs.append(drug)

count = 0
occurrences=[]
for drug in drugs:
  for element in data:
    if drug == element[0]:
      count += 1
  occurrences.append(count)  
  count = 0

dic = {drugs[i] : occurrences[i] for i in range(len(drugs))}  
print(dic)

plt.hist(dic.values(), bins=23)
plt.title("The number of side effects per drug", fontweight ="bold")
plt.xlabel("Number of side effects")
plt.ylabel("Frequency")
# Out:
 'CID100002369': 219, 'CID100002370': 22, 'CID100002375': 174, 'CID100002391': 23, 'CID100002405': 184, 'CID100002431': 28, 'CID100002435': 148, 'CID100002441': 58, 'CID100002442': 14, 'CID100002443': 144, 'CID100002462': 205, 'CID100002471': 49, 'CID100002474': 193, 'CID100002476': 196, 'CID100002477': 148, 'CID100002478': 225, 'CID100002479': 26, 'CID100002484': 5, 'CID100002487': 105, 'CID100002512': 111, 'CID100002519': 48, 'CID100002520': 123, 'CID100002522': 17, 'CID100002524': 87, 'CID100002540': 170, 'CID100002541': 71, 'CID100002547': 26, 'CID100002548': 61, 'CID100002550': 123, 'CID100002551': 22, 'CID100002554': 303, 'CID100002559': 25, 'CID100002563': 113, 'CID100002564': 43, 'CID100002576': 24, 'CID100002578': 158, 'CID100002583': 37, 'CID100002585': 212, 'CID100002609': 128, 'CID100002610': 53, 'CID100002617': 75, 'CID100002622': 85, 'CID100002631': 51, 'CID100002637': 57, 'CID100002646': 52, 'CID100002650': 80, 'CID100002654': 58, 'CID100002655': 39, 'CID100002656': 99, 'CID100002658': 112, 'CID100002662': 308, 'CID100002663': 39, 'CID100002666' ...
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Q3: The Most Frequent Side Effects
#
# Here, you are going to analyze side effects that can be more commonly caused by drugs.
#
# Since we have a dataset of drugs and their potential side effects, one of the first question that comes to mind is to see the most common side effects of these drugs.
#
# *   Plot a `bar chart` to show most frequent 15 side effects of the dataset.
#
# ![](https://i.ibb.co/Y8nQr3p/barh.jpg)
#
# *You can choose to make the bar chart with a different style, but the bars should look like the chart above.*

# %%
from collections import Counter
data = []
fname = "meddra_all_se.csv"
with open(join(path_prefix, fname)) as f:
  for line in f:
    rows = line.strip().split(",")
    stitch = str(rows[0])
    umls = str(rows[1])
    medra = str(rows[2])
    name = str(rows[3])
    data.append((stitch, umls, medra, name))

data = np.array(data)

elements = []
for row in data:
  side_effect=row[3]
  elements.append(side_effect)
print(elements)  

def FrequencyCounter(data):
  return Counter(data)

freq = FrequencyCounter(elements).most_common(15)
print(freq)
print()
plt.barh(range(len(freq)), [i[1] for i in freq])
plt.yticks(range(len(freq)), [j[0] for j in freq])

plt.xlabel("Frequency")
plt.ylabel("Side Effects")
plt.title("Top 15 Most Frequent Side Effects", fontweight ="bold")
plt.show()
# Out:
# ['Abdominal cramps', 'Abdominal pain', 'Amblyopia', 'Anaemia', 'Anorexia', 'Anxiety', 'Arrhythmia', 'Asthenia', 'Atrial fibrillation', 'Back pain', 'Bronchitis', 'Cardiovascular disorder', 'Chest pain', 'Infection', 'Constipation', 'Cough', 'Depression', 'Diarrhoea', 'Dizziness', 'Dysgeusia', 'Dyspepsia', 'Dyspnoea', 'Rash', 'Eye disorder', 'Body temperature increased', 'Gastritis', 'Gastrointestinal disorder', 'Headache', 'Haemorrhage', 'Hypercalcaemia', 'Hyperkalaemia', 'Hypersensitivity', 'Hypertension', 'Hypotension', 'Influenza', 'Cramps of lower extremities', 'Melaena', 'Hypertonia', 'Nausea', 'Pain', 'Palpitations', 'Parathyroid disorder', 'Paraesthesia', 'Pharyngitis', 'Pruritus', 'Renal failure', 'Rhinitis', 'Convulsion', 'Sinusitis', 'Tachycardia', 'Urinary tract infection', 'Angiopathy', 'Vertigo', 'Vomiting', 'Weight increased', 'Weight decreased', 'Body odor', 'Oedema peripheral', 'Injection site reaction', 'Accidental injury', 'Gastric atony', 'Myalgia', 'Gastrointestinal symptom NOS', 'Electrocardiogram abnormal', 'Fluid overload', 'Insomnia', 'Myasthenia', 'Drug dependence', 'Anaphylactic shock', 'Angioedema', 'Pain', 'Urticaria', 'Injection site tenderness', 'Anaemia', 'Aphasia', 'Mental disorder', 'Brain neoplasm', 'Infection', 'Diarrhoea', 'Oedema', 'Rash', 'Excoriation', 'Eye disorder', 'Body temperature increased', 'Gastrointestinal disorder', 'Glioma', 'Headache', 'Cardiac disorder', 'Hemianopia', 'Hemiparesis', 'Haemorrhage', 'Herpes simplex', 'Hyperpathia', 'Hypoaesthesia', 'Hypotension', 'Leukocytosis', 'Nausea', 'Neoplasm', 'Nervous system disorder', 'Nervousness', 'Pain', 'Paraesthesia', 'Petechiae', 'Pruritus', 'Respiratory insufficiency', 'Seborrhoeic dermatitis', 'Convulsion', 'Skin disorder', 'Sunburn', 'Thrombocytopenia', 'Thromboembolism', 'Ulcer', 'Erythema', 'Angiopathy', 'Vomiting', 'Chills', 'Rash pustular', 'Application site reaction', 'Gamma-glutamyltransferase increased', 'Skin hypertrophy', 'Aspartate aminotransferase increased', 'Alanine aminotransferase increased', 'Dry skin', 'Eyelid oedema', 'Photosensitivity reaction', 'Skin hyperpigmentation', 'Leukoderma', 'Unspecified disorder of skin and subcutaneous tissue', 'Scab', 'Welts', 'Discomfort', 'Tenderness', 'Skin exfoliation', 'Pustule', 'Skin tightness', 'Hepatobiliary disease', 'Blood bilirubin increased', 'Induration', 'Photosensitivity', 'Warmth', 'Dysaesthesia', 'Wound secretion', 'Rash maculo-papular', 'Application site irritation', 'Stinging', 'Skin carcinoma', 'Acne', 'Infestation NOS', 'Blood and lymphatic system disorders', 'Blood amylase increased', 'Accidental ingestion', 'Hyperkeratosis', 'Photodermatosis', 'Brain oedema', 'Photodamaged skin', 'Feeling hot', 'Alopecia', 'Anorexia', 'Infection', 'Constipation', 'Dermatitis', 'Diarrhoea', 'Rash', 'Extravasation', 'Fatigue', 'Hypersensitivity', 'Lethargy', 'Leukopenia', 'Nausea', 'Pruritus', 'Convulsion', 'Stomatitis', 'Thrombocytopenia', 'Erythema', 'Urticaria', 'Vomiting', 'Wheezing', 'Malaise', 'Anaphylactoid reaction', 'Serum creatinine increased', 'Febrile neutropenia', 'Sensitisation', 'Acute kidney injury', 'Body temperature increased', 'Syncope', 'Abdominal pain', 'Asthenia', 'Confusional state', 'Dysgeusia', 'Dyspepsia', 'Dyspnoea', 'Gastrointestinal disorder', 'Skin disorder', 'Kidney function abnormal', 'Decreased appetite', 'Abdominal pain upper', 'Abdominal pain lower', 'Abdominal tenderness', 'Disease progression', 'Caecitis', 'Rigors', 'Neuropathy', 'Sensitisation', 'Abdominal pain', 'Premature separation of placenta', 'Anaphylactic shock', 'Arrhythmia', 'Arthralgia', 'Asthenia', 'Asthma', 'Back pain', 'Bronchospasm', 'Chest pain', 'Cough', 'Dehydration', 'Diarrhoea', 'Disseminated intravascular coagulation', 'Dizziness', 'Dyspnoea', 'Amniotic fluid embolism', 'Endometritis', 'Rash', 'Foetal distress syndrome', 'Body temperature increased', 'Flushing', 'Headache', 'Cardiac arrest', 'Foetal heart rate', 'Hiccups', 'Hypersensitivity', 'Hypertension', 'Hypoten ...
# [('Nausea', 788), ('Headache', 737), ('Vomiting', 716), ('Rash', 693), ('Dizziness', 661), ('Diarrhoea', 643), ('Pruritus', 604), ('Hypersensitivity', 585), ('Urticaria', 519), ('Body temperature increased', 509), ('Abdominal pain', 497), ('Fatigue', 481), ('Constipation', 462), ('Dyspnoea', 456), ('Asthenia', 446)]

# %% [markdown]
# ## Q4: Conditional Probability
#
# In Probability Theory, conditional probability is a measure of the probability of an event occurring, given that another event has already occurred. The formula for the conditional probability is shared below.
#
# ```
# P(B|A) = P(A and B) / P(A)
# ```
#
# As also suggested by our dataset, drugs can have multiple side effects. With the conditional probability, we can study the chances of a particular side effect with a given presence of another one.
#
# So, the following question can be answered with our dataset.
#
# **If a drug has `Headache` side effect, what is the probability it also has `Vomiting` side effect?**
#
# Please calculate this conditional probability from the dataset and report the resulting probability score.

# %%
# P(Vomiting | Headache) = P(Vomiting and Headache) / P(Headache)

data = []
fname = "meddra_all_se.csv"
with open(join(path_prefix, fname)) as f:
  for line in f:
    rows = line.strip().split(",")
    stitch = str(rows[0])
    umls = str(rows[1])
    medra = str(rows[2])
    name = str(rows[3])
    data.append((stitch, umls, medra, name))

data = np.array(data)

count = 0
a = []
i=1
for i in range(len(data)):
  if data[i-1][3] == "Vomiting":  
    count+=1
  if data[i-1][3] == "Headache":
    count+=1    
  if data[i-1][0] != data[i][0]:
    a.append(count)
    count=0

count2= 0
a2 = []
j = 1
for j in range(len(data)):
  if data[j-1][3] == "Headache":
    count2 =1
  if data[j-1][0] != data[j][0]:
    a2.append(count2)
    count2=0

together = a.count(2)
probability1 = together/len(a)
alone = a2.count(1)
probability2 = alone/len(a)
final_probability = probability1/probability2
percentage ="{:.0%}".format(final_probability)
print("drug number:", len(a))
print("Headache and Vomiting number:", together)
print("probability of them together", probability1)
print("Only Headache number:", alone)
print("Probability of only headache:", probability2)
print("Probability of the asked question:", final_probability)
print("As a percentage:", percentage)
# Out:
# drug number: 953
# Headache and Vomiting number: 619
# probability of them together 0.6495278069254984
# Only Headache number: 736
# Probability of only headache: 0.7722980062959076
# Probability of the asked question: 0.8410326086956522
# As a percentage: 84%
